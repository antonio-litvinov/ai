# %%
from rich.jupyter import print as pprint

# %%
def chat(thread_id: str):
    config = {"configurable": {"thread_id": thread_id}}

    while(True):
        rq = input("\nХозяин: ")
        if rq == "":
            break
        resp = agent.invoke({"messages": [("user", rq)]}, config=config)
        print("Петрушка: ", resp["messages"][-1].content)
        time.sleep(1)

# %%
from langchain.prompts import ChatPromptTemplate

# %%
chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", "Системник"),
        ("user", "Пользак"),
    ]
)

# %%
pprint(chat_template)
# Out:
# ChatPromptTemplate(
#     input_variables=[],
#     input_types={},
#     partial_variables={},
#     messages=[
#         SystemMessagePromptTemplate(
#             prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Системник'),
#             additional_kwargs={}
#         ),
#         HumanMessagePromptTemplate(
#             prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Пользак'),
#             additional_kwargs={}
#         )
#     ]
# )

# %% [markdown]
# ![Снимок экрана 2025-06-05 в 00.45.50.png](attachment:be06181d-a6ee-471d-83c4-dd821a567889.png)
